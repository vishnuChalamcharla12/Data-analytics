# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnuChalamcharla12/Data-analytics/blob/main/Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the dataset
toyota = pd.read_csv("/content/ToyotaCorolla (1).csv")

# Check the structure of the dataset
str(toyota) # for a concise summary or
toyota.info() # for a more detailed overview
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 1436 non-null   int64
#  1   Model              1436 non-null   object
#  2   Price              1436 non-null   int64
#  3   Age (month)        1436 non-null   int64
#  4   Mfg_Month          1436 non-null   int64
#  5   Mfg_Year           1436 non-null   int64
#  6   KM                 1436 non-null   int64
#  7   Fuel_Type          1436 non-null   object
#  8   HP                 1436 non-null   int64
#  9   Met_Color          1436 non-null   int64
#  10  Color              1436 non-null   object
#  11  Automatic          1436 non-null   int64
#  12  CC                 1436 non-null   int64
#  13  Doors              1436 non-null   int64
#  14  Cylinders          1436 non-null   int64
#  15  Gears              1436 non-null   int64
#  16  Quarterly_Tax      1436 non-null   int64
#  17  Weight             1436 non-null   int64
#  18  Mfr_Guarantee      1436 non-null   int64
#  19  Dealer_Guarantee   1436 non-null   int64
#  20  Guarantee_Period   1436 non-null   int64
#  21  ABS                1436 non-null   int64
#  22  Airbag_1           1436 non-null   int64
#  23  Airbag_2           1436 non-null   int64
#  24  Aircond            1436 non-null   int64
#  25  Automatic_aircond  1436 non-null   int64
#  26  Boardcomputer      1436 non-null   int64
#  27  CD_Player          1436 non-null   int64
#  28  Central_Lock       1436 non-null   int64
#  29  Powered_Windows    1436 non-null   int64
#  30  Power_Steering     1436 non-null   int64
#  31  Radio              1436 non-null   int64
#  32  Mistlamps          1436 non-null   int64
#  33  Sport_Model        1436 non-null   int64
#  34  Backseat_Divider   1436 non-null   int64
#  35  Metallic_Rim       1436 non-null   int64
#  36  Radio_cassette     1436 non-null   int64
#  37  Parking_Assistant  1436 non-null   int64
#  38  Tow_Bar            1436 non-null   int64
# dtypes: int64(36), object(3)
# memory usage: 437.7+ KB

# %% [markdown]
# A categorical variable represents different categories or groups. For example, a variable like Color might contain values like "Red", "Blue", and "Green". These values are non-numeric and cannot be used directly in statistical models.
# To handle this, dummy variables (binary variables) are created. For a categorical variable with N categories, we create N-1 dummy variables (also called "one-hot encoding"). Each dummy variable takes a value of 1 or 0, indicating the presence or absence of a particular category.
# For example, if the Color variable has three categories: "Red", "Blue", and "Green", we will create two dummy variables:
# Color_Red (1 if the color is Red, 0 otherwise)
# Color_Blue (1 if the color is Blue, 0 otherwise)
# The third category, "Green", is implicitly represented when both Color_Red and Color_Blue are 0.

# %% [markdown]
# If a categorical variable has N categories, then you need N-1 dummy variables. This is because one category can be used as a reference category, and the remaining categories are represented with binary indicators.
# For example, if you have a variable Color with 4 categories (Red, Blue, Green, Yellow), you need 3 dummy variables:
# Color_Red
# Color_Blue
# Color_Green
# Yellow is implicitly represented when the other three variables are 0.

# %%
import pandas as pd

# Assuming 'toyota' is a pandas DataFrame loaded previously
toyota_dummies = pd.get_dummies(toyota, drop_first=True)

# Display the first few rows of the dummy variables
toyota_dummies.head()
# Out:
#    Id  Price  Age (month)  Mfg_Month  Mfg_Year     KM  HP  Met_Color  \
# 0   1  13500           23         10      2002  46986  90          1
# 1   2  13750           23         10      2002  72937  90          1
# 2   3  13950           24          9      2002  41711  90          1
# 3   4  14950           26          7      2002  48000  90          0
# 4   5  13750           30          3      2002  38500  90          0
#
#    Automatic    CC  ...  Fuel_Type_Petrol  Color_Black  Color_Blue  \
# 0          0  2000  ...             False        False        True
# 1          0  2000  ...             False        False       False
# 2          0  2000  ...             False        False        True
# 3          0  2000  ...             False         True       False
# 4          0  2000  ...             False         True       False
#
#    Color_Green  Color_Grey  Color_Red  Color_Silver  Color_Violet  \
# 0        False       False      False         False         False
# 1        False       False      False          True         False
# 2        False       False      False         False         False
# 3        False       False      False         False         False
# 4        False       False      False         False         False
#
#    Color_White  Color_Yellow
# 0        False         False
# 1        False         False
# 2        False         False
# 3        False         False
# 4        False         False
#
# [5 rows x 365 columns]

# %%
# prompt:  Use R to convert the categorical variables in this dataset into dummy variables, and explain in words, for one record, the values in the derived binary dummies.

import pandas as pd

# Load the dataset
toyota = pd.read_csv("/content/ToyotaCorolla (1).csv")

# Select categorical columns (you might need to adjust this based on your actual data)
categorical_cols = toyota.select_dtypes(include=['object']).columns

# Convert categorical variables to dummy variables
toyota_dummies = pd.get_dummies(toyota, columns=categorical_cols, drop_first=True)

# Display the first few rows of the dataset with dummy variables
print(toyota_dummies.head())

# Example explanation for one record (first row)

# Get the first row of the original data
first_row_original = toyota.iloc[0]

# Get the first row of the transformed data with dummy variables.
first_row_dummies = toyota_dummies.iloc[0]

print("\nOriginal Data (First Row):")
print(first_row_original)

print("\nDummy Variables (First Row):")
print(first_row_dummies)


print("\nExplanation for the first row:")

for col in categorical_cols:
    original_value = first_row_original[col]
    dummy_col_prefix = col + "_"

    print(f"\nOriginal value of {col} is {original_value}")

    for dummy_col in toyota_dummies.columns:
        if dummy_col.startswith(dummy_col_prefix):
            if first_row_dummies[dummy_col] == 1:
                print(f"Dummy variable {dummy_col} is 1, indicating that the {col} was {dummy_col.replace(dummy_col_prefix, '')}")
            else:
                print(f"Dummy variable {dummy_col} is 0, indicating that the {col} was NOT {dummy_col.replace(dummy_col_prefix, '')}")
# Out:
#    Id  Price  Age (month)  Mfg_Month  Mfg_Year     KM  HP  Met_Color  \
# 0   1  13500           23         10      2002  46986  90          1
# 1   2  13750           23         10      2002  72937  90          1
# 2   3  13950           24          9      2002  41711  90          1
# 3   4  14950           26          7      2002  48000  90          0
# 4   5  13750           30          3      2002  38500  90          0
#
#    Automatic    CC  ...  Fuel_Type_Petrol  Color_Black  Color_Blue  \
# 0          0  2000  ...             False        False        True
# 1          0  2000  ...             False        False       False
# 2          0  2000  ...             False        False        True
# 3          0  2000  ...             False         True       False
# 4          0  2000  ...             False         True       False
#
#    Color_Green  Color_Grey  Color_Red  Color_Silver  Color_Violet  \
# 0        False       False      False         False         False
# 1        False       False      False          True         False
# 2        False       False      False         False         False
# 3        False       False      False         False         False
# 4        False       False      False         False         False
#
#    Color_White  Color_Yellow
# 0        False         False
# 1        False         False
# 2        False         False
# 3        False         False
# 4        False         False
#
# [5 rows x 365 columns]
#
# Original Data (First Row):
# Id                                                               1
# Model                TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors
# Price                                                        13500
# Age (month)                                                     23
# Mfg_Month                                                       10
# Mfg_Year                                                      2002
# KM                                                           46986
# Fuel_Type                                                   Diesel
# HP                                                              90
# Met_Color                                                        1
# Color                                                         Blue
# Automatic                                                        0
# CC                                                            2000
# Doors                                                            3
# Cylinders                                                        4
# Gears                                                            5
# Quarterly_Tax                                                  210
# Weight                                                        1165
# Mfr_Guarantee                                                    0
# Dealer_Guarantee                                                 1
# Guarantee_Period                                                 3
# ABS                                                              1
# Airbag_1                                                         1
# Airbag_2                                                         1
# Aircond                                                          0
# Automatic_aircond                                                0
# Boardcomputer                                                    1
# CD_Player                                                        0
# Central_Lock                                                     1
# Powered_Windows                                                  1
# Power_Steering                                                   1
# Radio                                                            0
# Mistlamps                                                        0
# Sport_Model                                                      0
# Backseat_Divider                                                 1
# Metallic_Rim                                                     0
# Radio_cassette                                                   0
# Parking_Assistant                                                0
# Tow_Bar                                                          0
# Name: 0, dtype: object
#
# Dummy Variables (First Row):
# Id                  1
# Price           13500
# Age (month)        23
# Mfg_Month          10
# Mfg_Year         2002
#                 ...
# Color_Red       False
# Color_Silver    False
# Color_Violet    False
# Color_White     False
# Color_Yellow    False
# Name: 0, Length: 365, dtype: object
#
# Explanation for the first row:
#
# Original value of Model is TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors
# Dummy variable Model_TOYOTA Corolla ! 1.6-16v vvt-i sol airco sedan 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla ! 1.6-16v vvt-i sol airco sedan 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1 6-16v VVT-i Linea Terra Comfort Airco 5drs 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1 6-16v VVT-i Linea Terra Comfort Airco 5drs 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V HATCHB 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V HATCHB 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V HATCHB LINEA LUNA 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V HATCHB LINEA LUNA 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V HATCHB LINEA LUNA AUT3 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V HATCHB LINEA LUNA AUT3 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA AUT3 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA AUT3 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V HATCHB S 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V HATCHB S 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V L. TERRA COMFORT 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V L. TERRA COMFORT 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V LB Linea Luna 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V LB Linea Luna 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V LIFTB G6 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V LIFTB G6 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V LIFTB LINEA LUNA 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V LIFTB LINEA LUNA 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V LIFTB LINEA TERRA 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V LIFTB LINEA TERRA 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V LIFTB LINEA TERRA AUT3 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V LIFTB LINEA TERRA AUT3 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V Linea Terra 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V Linea Terra 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V Linea Terra 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V Linea Terra 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V Linea Terra Liftb 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V Linea Terra Liftb 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V Linea Terra Liftb 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V Linea Terra Liftb 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V SEDAN LINEA TERRA 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V SEDAN LINEA TERRA 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V SEDAN LINEA TERRA AUT3 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V SEDAN LINEA TERRA AUT3 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 16V WAGON LINEA LUNA Stationwagen is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V WAGON LINEA LUNA Stationwagen
# Dummy variable Model_TOYOTA Corolla 1.3 16V WAGON LINEA TERRA Stationwagen is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16V WAGON LINEA TERRA Stationwagen
# Dummy variable Model_TOYOTA Corolla 1.3 16v linea terra  is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 16v linea terra
# Dummy variable Model_TOYOTA Corolla 1.3 3D Linea Terra 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 3D Linea Terra 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 G6 liftback 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 G6 liftback 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 HB LINEA TERRA 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 HB LINEA TERRA 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 HB LINEA TERRA AUT 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.3 HB LINEA TERRA AUT 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.3 HB LINEA TERRA AUT Anders is 0, indicating that the Model was NOT TOYOTA Corolla 1.3
4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.6i 16V VVT I SOL + Navigatie 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.6i Linea Terra HB 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.6i Linea Terra HB 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.6i-16 SPORTS TC 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.6i-16 SPORTS TC 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.6v VVT-i Linea Sol 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.6v VVT-i Linea Sol 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.8 16V VVTLI 3DR T SPORT 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.8 16V VVTLI 3DR T SPORT 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.8 16V VVTLI 3DR T SPORT BNS 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.8 16V VVTLI 3DR T SPORT BNS 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.8 16V VVTLI 5DR T SPORT 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.8 16V VVTLI 5DR T SPORT 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.8 VVTL-i T-Sport 3-Drs 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.8 VVTL-i T-Sport 3-Drs 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.8 VVTL-i T-Sport 3-Drs 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.8 VVTL-i T-Sport 3-Drs 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.8 VVTL-i T-Sport 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.8 VVTL-i T-Sport 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.8D 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.8D 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.8D Stationwagen is 0, indicating that the Model was NOT TOYOTA Corolla 1.8D Stationwagen
# Dummy variable Model_TOYOTA Corolla 1.9 D HATCHB SOL 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.9 D HATCHB SOL 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.9 D HATCHB TERRA 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.9 D HATCHB TERRA 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.9 D HB SOL 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.9 D HB SOL 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.9 D LB LINEA SOL 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.9 D LB LINEA SOL 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.9 D LIFTB LUNA 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.9 D LIFTB LUNA 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.9 D LIFTB TERRA 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.9 D LIFTB TERRA 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.9 D Linea Terra 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.9 D Linea Terra 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 1.9 D SEDAN TERRA 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.9 D SEDAN TERRA 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.9 D Sedan 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1.9 D Sedan 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 1.9 D WAGON TERRA Stationwagen is 0, indicating that the Model was NOT TOYOTA Corolla 1.9 D WAGON TERRA Stationwagen
# Dummy variable Model_TOYOTA Corolla 1.9 D WGN LINEA TERRA Stationwagen is 0, indicating that the Model was NOT TOYOTA Corolla 1.9 D WGN LINEA TERRA Stationwagen
# Dummy variable Model_TOYOTA Corolla 1.9 D Wagon Stationwagen is 0, indicating that the Model was NOT TOYOTA Corolla 1.9 D Wagon Stationwagen
# Dummy variable Model_TOYOTA Corolla 1800 T SPORT VVT I 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 1800 T SPORT VVT I 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 19D LB Linea Terra 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 19D LB Linea Terra 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D 4D Linea Sol 3 Doors 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D 4D Linea Sol 3 Doors 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D Linea Terra 3d 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D Linea Terra 3d 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D Linea Terra Liftback 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D Linea Terra Liftback 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D Linea luna Wagon Stationwagen is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D Linea luna Wagon Stationwagen
# Dummy variable Model_TOYOTA Corolla 2.0 D4D 110 3DR SOL 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D4D 110 3DR SOL 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D4D 110 5DR EXEC BNS 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D4D 110 5DR EXEC BNS 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D4D 110 5DR SOL 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D4D 110 5DR SOL 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D4D 116 5DR LUNA 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D4D 116 5DR LUNA 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D4D 90 3DR SOL BNS 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D4D 90 3DR SOL BNS 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D4D 90 3DR TERRA 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D4D 90 3DR TERRA 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D4D 90 3DR TERRA COMF BNS 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D4D 90 3DR TERRA COMF BNS 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D4D 90 5DR SOL 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D4D 90 5DR SOL 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D4D 90 5DR TERRA 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D4D 90 5DR TERRA 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D4D 90 5DR TERRA COMFORT 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D4D 90 5DR TERRA COMFORT 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D4D 90 WAGON SOL Stationwagen is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D4D 90 WAGON SOL Stationwagen
# Dummy variable Model_TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors is 1, indicating that the Model was TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D4D LIFTB SOL 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D4D LIFTB SOL 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D4D Linea Sol 3 Doors 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D4D Linea Sol 3 Doors 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D4D Linea Terra Comfort 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D4D Linea Terra Comfort 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 D4D SEDAN SOL 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 D4D SEDAN SOL 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 DSL  is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 DSL
# Dummy variable Model_TOYOTA Corolla 2.0 DSL HATCHB LINEA LUNA 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 DSL HATCHB LINEA LUNA 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 DSL HATCHB LINEA TERRA 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 DSL HATCHB LINEA TERRA 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 DSL LIFTB LINEA LUNA 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 DSL LIFTB LINEA LUNA 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 DSL LIFTB LINEA TERRA 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 DSL LIFTB LINEA TERRA 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 DSL SEDAN LINEA TERRA 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 DSL SEDAN LINEA TERRA 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 DSL WAGON LINEA TERRA COMM Anders is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 DSL WAGON LINEA TERRA COMM Anders
# Dummy variable Model_TOYOTA Corolla 2.0 DSL WAGON LINEA TERRA Stationwagen is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 DSL WAGON LINEA TERRA Stationwagen
# Dummy variable Model_TOYOTA Corolla 2.0 LB LINEA TERRA D 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 LB LINEA TERRA D 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 LB LINEA TERRA DSL 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 LB LINEA TERRA DSL 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 SDN LINEA TERRA DSL 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 SDN LINEA TERRA DSL 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0 ST WGN LINEA TERRA DSL Stationwagen is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 ST WGN LINEA TERRA DSL Stationwagen
# Dummy variable Model_TOYOTA Corolla 2.0 d HB Diesel 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0 d HB Diesel 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 2.0D 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0D 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0D LINEA TERRA+airco 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0D LINEA TERRA+airco 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 2.0D Linea Terra 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0D Linea Terra 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 2.0D TERRA LIFTBACK 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0D TERRA LIFTBACK 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0D XL Sedan 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2.0D XL Sedan 4/5-Doors
# Dummy variable Model_TOYOTA Corolla 2.0diesel Stationwagen is 0, indicating that the Model was NOT TOYOTA Corolla 2.0diesel Stationwagen
# Dummy variable Model_TOYOTA Corolla 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 2/3-Doors
# Dummy variable Model_TOYOTA Corolla 3drs 13i-16V 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla 3drs 13i-16V 2/3-Doors
# Dummy variable Model_TOYOTA Corolla Hatchback 1.6 Terra Comfort 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla Hatchback 1.6 Terra Comfort 2/3-Doors
# Dummy variable Model_TOYOTA Corolla LIFTBACK 1.3i Linea Luna Liftback 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla LIFTBACK 1.3i Linea Luna Liftback 4/5-Doors
# Dummy variable Model_TOYOTA Corolla LIFTBACK 1.3i Linea Terra Liftback 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla LIFTBACK 1.3i Linea Terra Liftback 4/5-Doors
# Dummy variable Model_TOYOTA Corolla LIFTBACK 1.4 16V VVTI TERRA 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla LIFTBACK 1.4 16V VVTI TERRA 4/5-Doors
# Dummy variable Model_TOYOTA Corolla LIFTBACK 1.4 VVT-i LINEA TERRA 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla LIFTBACK 1.4 VVT-i LINEA TERRA 4/5-Doors
# Dummy variable Model_TOYOTA Corolla LIFTBACK 1.6 Linea Luna Liftback 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla LIFTBACK 1.6 Linea Luna Liftback 4/5-Doors
# Dummy variable Model_TOYOTA Corolla LIFTBACK 1.6 Linea Sol 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla LIFTBACK 1.6 Linea Sol 4/5-Doors
# Dummy variable Model_TOYOTA Corolla LIFTBACK 1.6 Linea Terra Liftback 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla LIFTBACK 1.6 Linea Terra Liftback 4/5-Doors
# Dummy variable Model_TOYOTA Corolla LIFTBACK 1.6 Linea terra 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla LIFTBACK 1.6 Linea terra 4/5-Doors
# Dummy variable Model_TOYOTA Corolla LIFTBACK 1.6-16v Linea Luna 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla LIFTBACK 1.6-16v Linea Luna 2/3-Doors
# Dummy variable Model_TOYOTA Corolla LIFTBACK 1.6-16v Linea Luna 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla LIFTBACK 1.6-16v Linea Luna 4/5-Doors
# Dummy variable Model_TOYOTA Corolla LIFTBACK 1.9 D Linea Terra 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla LIFTBACK 1.9 D Linea Terra 4/5-Doors
# Dummy variable Model_TOYOTA Corolla Liftback 1.6 VVTI 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla Liftback 1.6 VVTI 4/5-Doors
# Dummy variable Model_TOYOTA Corolla Linea Luna 1.6i 16V 2/3-Doors is 0, indicating that the Model was NOT TOYOTA Corolla Linea Luna 1.6i 16V 2/3-Doors
# Dummy variable Model_TOYOTA Corolla Luna 5drs D4D116 PK 4/5-Doors is 0, indicating that the Model was NOT TOYOTA Corolla Luna 5drs D4D116 PK 4/5-Doors
# Dummy variable Model_TOYOTA Corolla Sw 20D Linea Terra Stationwagen is 0, indicating that the Model was NOT TOYOTA Corolla Sw 20D Linea Terra Stationwagen
# Dummy variable Model_TOYOTA Corolla VERSO 2.0 D4D LINEA SOL MPV is 0, indicating that the Model was NOT TOYOTA Corolla VERSO 2.0 D4D LINEA SOL MPV
# Dummy variable Model_TOYOTA Corolla VERSO 2.0 D4D SOL (7) BNS MPV is 0, indicating that the Model was NOT TOYOTA Corolla VERSO 2.0 D4D SOL (7) BNS MPV
# Dummy variable Model_TOYOTA Corolla VERSO 2.0 D4D SOL (7) MPV is 0, indicating that the Model was NOT TOYOTA Corolla VERSO 2.0 D4D SOL (7) MPV
#
# Original value of Fuel_Type is Diesel
# Dummy variable Fuel_Type_Diesel is 1, indicating that the Fuel_Type was Diesel
# Dummy variable Fuel_Type_Petrol is 0, indicating that the Fuel_Type was NOT Petrol
#
# Original value of Color is Blue
# Dummy variable Color_Black is 0, indicating that the Color was NOT Black
# Dummy variable Color_Blue is 1, indicating that the Color was Blue
# Dummy variable Color_Green is 0, indicating that the Color was NOT Green
# Dummy variable Color_Grey is 0, indicating that the Color was NOT Grey
# Dummy variable Color_Red is 0, indicating that the Color was NOT Red
# Dummy variable Color_Silver is 0, indicating that the Color was NOT Silver
# Dummy variable Color_Violet is 0, indicating that the Color was NOT Violet
# Dummy variable Color_White is 0, indicating that the Color was NOT White
# Dummy variable Color_Yellow is 0, indicating that the Color was NOT Yellow

# %%
# prompt: Use R to produce a correlation matrix and matrix plot. Comment on the relationships among variables.

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'toyota_dummies' DataFrame is already created as in the previous code

# Select numerical columns for correlation analysis
# Include 'Age' (or 'Age_08_04' if it exists) and 'Price' in the numerical columns
numerical_cols = toyota_dummies.select_dtypes(include=['number']).columns
# If 'Age' is the original column name, use it, otherwise check for variations
if 'Age' in toyota_dummies.columns:
    numerical_cols = numerical_cols.union(['Age', 'Price'])
else:
    # Check for potential renamed columns like 'Age_08_04' or similar
    age_cols = [col for col in toyota_dummies.columns if col.startswith('Age')]
    if age_cols:
        numerical_cols = numerical_cols.union(age_cols).union(['Price'])
    else:
        print("Warning: 'Age' column or its variations not found in toyota_dummies. Check data.")

# Calculate the correlation matrix
correlation_matrix = toyota_dummies[numerical_cols].corr()

# Create a heatmap of the correlation matrix
plt.figure(figsize=(12, 10))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Numerical Variables')
plt.show()


# Further analysis (example)
# You can identify highly correlated variables from the heatmap
# and explore their relationships further.  For instance:

# Example:  Check the relationship between 'Age' (or 'Age_08_04') and 'Price'
if 'Age' in toyota_dummies.columns:
    print(toyota_dummies[['Age', 'Price']].corr())  # Use 'Age' if it exists
else:
    if age_cols:  # Use the first found age column if 'Age' is not present
        print(toyota_dummies[[age_cols[0], 'Price']].corr())
    else:
        print("Warning: 'Age' column or its variations not found for correlation analysis.")

# Scatter Plot for visual inspection
if 'Age' in toyota_dummies.columns:
    plt.figure(figsize=(8, 6))
    plt.scatter(toyota_dummies['Age'], toyota_dummies['Price'])
    plt.xlabel('Age')
    plt.ylabel('Price')
    plt.title('Relationship between Age and Price')
    plt.show()
else:
    if age_cols:  # Use the first found age column if 'Age' is not present
        plt.figure(figsize=(8, 6))
        plt.scatter(toyota_dummies[age_cols[0]], toyota_dummies['Price'])
        plt.xlabel(age_cols[0])
        plt.ylabel('Price')
        plt.title(f'Relationship between {age_cols[0]} and Price')
        plt.show()
    else:
        print("Warning: 'Age' column or its variations not found for scatter plot.")

# Comments on Relationships:
# Examine the heatmap and individual plots to describe the correlations.
# For example:
# "There is a strong negative correlation between Age and Price, as expected.
#  Older cars tend to have lower prices."

# You would analyze other pairs of variables similarly and provide a more comprehensive
# commentary based on the observations in the correlation matrix and plots
# Out:
#              Age (month)    Price
# Age (month)      1.00000 -0.87659
# Price           -0.87659  1.00000
