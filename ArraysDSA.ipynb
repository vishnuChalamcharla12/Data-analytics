# %% [markdown]
# <a href="https://colab.research.google.com/github/vishnuChalamcharla12/Data-analytics/blob/main/ArraysDSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Array-Data struvtures - Day 1

# %%
stock_prices=[298,305,320,301,292]

# %%
# what was the price on day 3?
stock_prices[2]
#Complexity logic on Array -Stock_prices[2]->0*500+2*sizeof(integer) here size =4
# Out:
# 320

# %%
for i in range(len(stock_prices)):
    if stock_prices[i]==301:
        print(i)
# Out:
# 3

# %%
Monthly_expenses={
'January':2200,
'February':2350,
'March':2600,
'April':2130,
'May':2190,
}

# %%
#In Feb, how many dollars you spent extra compare to January?
extra_spent=Monthly_expenses['February']-Monthly_expenses['January']
print(extra_spent)
# Out:
# 150

# %%
#Find out your total expense in first quarter (first three months) of the year.
months_spent=Monthly_expenses['February']+Monthly_expenses['January']+Monthly_expenses['January']++Monthly_expenses['March']
print(months_spent)
# Out:
# 9350

# %%
# Find out if you spent exactly 2000 dollars in any month
for month,expenses in Monthly_expenses.items:
    if Monthly_expenses[i]==2000:
      print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2724571453.py in <cell line: 0>()
#       1 # Find out if you spent exactly 2000 dollars in any month
# ----> 2 for month,expenses in Monthly_expenses.items:
#       3     if Monthly_expenses[i]==2000:
#       4       print(i)
#       5
#
# TypeError: 'builtin_function_or_method' object is not iterable
